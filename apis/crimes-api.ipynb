# %% [markdown]
# ## Toronto Crime Analysis

# %% [markdown]
# ### This notebook reads crime data from the Toronto Police API in chunks (due to API limit), combines and cleans it, and converts it to a csv, to be imported by other notebooks in this project

# %%
import requests
import json
import pandas as pd
from pprint import pprint
from pandas.io.json import json_normalize
from IPython.display import clear_output

# %%
# Toronto police major crime indicator data:
mci_data = requests.get('https://services.arcgis.com/S9th0jAJ7bqgIRjw/arcgis/rest/services/MCI_2014_2017/FeatureServer/0/query?where=occurrenceyear%20%3E%3D%202014%20AND%20occurrenceyear%20%3C%3D%202014%20AND%20UPPER(occurrencemonth)%20like%20%27%25JANUARY%25%27&outFields=*&outSR=4326&f=json').json()

# %%
mci_data.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'geometryType', 'spatialReference', 'fields', 'features', 'exceededTransferLimit'])

# %%
# look into each key:
mci_data['objectIdFieldName']
# Out:
# 'FID'

# %%
# only 'features' key has any actual data
mci_data['features']
# Out:
# [{'attributes': {'Index_': 701,
#    'event_unique_id': 'GO-20141410316',
#    'occurrencedate': 1390626000000,
#    'reporteddate': 1390626000000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 25,
#    'reporteddayofyear': 25,
#    'reporteddayofweek': 'Saturday  ',
#    'reportedhour': 20,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 25,
#    'occurrencedayofyear': 25,
#    'occurrencedayofweek': 'Saturday  ',
#    'occurrencehour': 20,
#    'MCI': 'Assault',
#    'Division': 'D43',
#    'Hood_ID': 127,
#    'Neighbourhood': 'Bendale (127)',
#    'Lat': 43.7544174,
#    'Long': -79.2509308,
#    'FID': 103},
#   'geometry': {'x': -79.2509308, 'y': 43.7544174}},
#  {'attributes': {'Index_': 702,
#    'event_unique_id': 'GO-20141411089',
#    'occurrencedate': 1390626000000,
#    'reporteddate': 1390626000000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 25,
#    'reporteddayofyear': 25,
#    'reporteddayofweek': 'Saturday  ',
#    'reportedhour': 23,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 25,
#    'occurrencedayofyear': 25,
#    'occurrencedayofweek': 'Saturday  ',
#    'occurrencehour': 22,
#    'MCI': 'Assault',
#    'Division': 'D13',
#    'Hood_ID': 108,
#    'Neighbourhood': 'Briar Hill-Belgravia (108)',
#    'Lat': 43.6959,
#    'Long': -79.4493332,
#    'FID': 107},
#   'geometry': {'x': -79.4493332, 'y': 43.6959}},
#  {'attributes': {'Index_': 703,
#    'event_unique_id': 'GO-20141410304',
#    'occurrencedate': 1390626000000,
#    'reporteddate': 1390626000000,
#    'premisetype': 'Commercial',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 25,
#    'reporteddayofyear': 25,
#    'reporteddayofweek': 'Saturday  ',
#    'reportedhour': 20,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 25,
#    'occurrencedayofyear': 25,
#    'occurrencedayofweek': 'Saturday  ',
#    'occurrencehour': 20,
#    'MCI': 'Assault',
#    'Division': 'D33',
#    'Hood_ID': 45,
#    'Neighbourhood': 'Parkwoods-Donalda (45)',
#    'Lat': 43.7522316,
#    'Long': -79.3318024,
#    'FID': 166},
#   'geometry': {'x': -79.33180239999999, 'y': 43.752231599999995}},
#  {'attributes': {'Index_': 704,
#    'event_unique_id': 'GO-20141410500',
#    'occurrencedate': 1390626000000,
#    'reporteddate': 1390626000000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 25,
#    'reporteddayofyear': 25,
#    'reporteddayofweek': 'Saturday  ',
#    'reportedhour': 21,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 25,
#    'occurrencedayofyear': 25,
#    'occurrencedayofweek': 'Saturday  ',
#    'occurrencehour': 21,
#    'MCI': 'Break and Enter',
#    'Division': 'D53',
#    'Hood_ID': 103,
#    'Neighbourhood': 'Lawrence Park South (103)',
#    'Lat': 43.7171288,
#    'Long': -79.418251,
#    'FID': 280},
#   'geometry': {'x': -79.418251, 'y': 43.71712879999998}},
#  {'attributes': {'Index_': 705,
#    'event_unique_id': 'GO-20141410257',
#    'occurrencedate': 1390626000000,
#    'reporteddate': 1390626000000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 25,
#    'reporteddayofyear': 25,
#    'reporteddayofweek': 'Saturday  ',
#    'reportedhour': 20,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 25,
#    'occurrencedayofyear': 25,
#    'occurrencedayofweek': 'Saturday  ',
#    'occurrencehour': 15,
#    'MCI': 'Break and Enter',
#    'Division': 'D53',
#    'Hood_ID': 103,
#    'Neighbourhood': 'Lawrence Park South (103)',
#    'Lat': 43.7149734,
#    'Long': -79.4174118,
#    'FID': 319},
#   'geometry': {'x': -79.4174118, 'y': 43.71497339999999}},
#  {'attributes': {'Index_': 706,
#    'event_unique_id': 'GO-20141461372',
#    'occurrencedate': 1390626000000,
#    'reporteddate': 1391403600000,
#    'premisetype': 'Apartment',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'February',
#    'reportedday': 3,
#    'reporteddayofyear': 34,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 12,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 25,
#    'occurrencedayofyear': 25,
#    'occurrencedayofweek': 'Saturday  ',
#    'occurrencehour': 15,
#    'MCI': 'Break and Enter',
#    'Division': 'D13',
#    'Hood_ID': 102,
#    'Neighbourhood': 'Forest Hill North (102)',
#    'Lat': 43.6998558,
#    'Long': -79.4309082,
#    'FID': 320},
#   'geometry': {'x': -79.43090819999999, 'y': 43.699855799999995}},
#  {'attributes': {'Index_': 707,
#    'event_unique_id': 'GO-20141473117',
#    'occurrencedate': 1390626000000,
#    'reporteddate': 1391576400000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'February',
#    'reportedday': 5,
#    'reporteddayofyear': 36,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 10,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 25,
#    'occurrencedayofyear': 25,
#    'occurrencedayofweek': 'Saturday  ',
#    'occurrencehour': 14,
#    'MCI': 'Break and Enter',
#    'Division': 'D32',
#    'Hood_ID': 39,
#    'Neighbourhood': 'Bedford Park-Nortown (39)',
#    'Lat': 43.7289124,
#    'Long': -79.4245834,
#    'FID': 322},
#   'geometry': {'x': -79.4245834, 'y': 43.7289124}},
#  {'attributes': {'Index_': 708,
#    'event_unique_id': 'GO-20141411290',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1420,
#    'ucr_ext': 110,
#    'offence': 'Assault Bodily Harm',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 3,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D22',
#    'Hood_ID': 13,
#    'Neighbourhood': 'Etobicoke West Mall (13)',
#    'Lat': 43.6523972,
#    'Long': -79.5722122,
#    'FID': 323},
#   'geometry': {'x': -79.5722122, 'y': 43.65239720000001}},
#  {'attributes': {'Index_': 801,
#    'event_unique_id': 'GO-20141419186',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1420,
#    'ucr_ext': 100,
#    'offence': 'Assault With Weapon',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 13,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 13,
#    'MCI': 'Assault',
#    'Division': 'D43',
#    'Hood_ID': 139,
#    'Neighbourhood': 'Scarborough Village (139)',
#    'Lat': 43.7451057,
#    'Long': -79.2197266,
#    'FID': 324},
#   'geometry': {'x': -79.21972659999999, 'y': 43.7451057}},
#  {'attributes': {'Index_': 709,
#    'event_unique_id': 'GO-20141412367',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Commercial',
#    'ucr_code': 1610,
#    'ucr_ext': 100,
#    'offence': 'Robbery With Weapon',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 7,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 7,
#    'MCI': 'Robbery',
#    'Division': 'D54',
#    'Hood_ID': 61,
#    'Neighbourhood': 'Taylor-Massey (61)',
#    'Lat': 43.6902275,
#    'Long': -79.2926865,
#    'FID': 326},
#   'geometry': {'x': -79.2926865, 'y': 43.69022749999999}},
#  {'attributes': {'Index_': 802,
#    'event_unique_id': 'GO-20141419186',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1410,
#    'ucr_ext': 100,
#    'offence': 'Aggravated Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 13,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 13,
#    'MCI': 'Assault',
#    'Division': 'D43',
#    'Hood_ID': 139,
#    'Neighbourhood': 'Scarborough Village (139)',
#    'Lat': 43.7451057,
#    'Long': -79.2197266,
#    'FID': 327},
#   'geometry': {'x': -79.21972659999999, 'y': 43.7451057}},
#  {'attributes': {'Index_': 803,
#    'event_unique_id': 'GO-20141419549',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'Other',
#    'ucr_code': 1420,
#    'ucr_ext': 110,
#    'offence': 'Assault Bodily Harm',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 14,
#    'MCI': 'Assault',
#    'Division': 'D43',
#    'Hood_ID': 135,
#    'Neighbourhood': 'Morningside (135)',
#    'Lat': 43.7903175,
#    'Long': -79.1979752,
#    'FID': 364},
#   'geometry': {'x': -79.1979752, 'y': 43.790317499999986}},
#  {'attributes': {'Index_': 710,
#    'event_unique_id': 'GO-20141413042',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 11,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 11,
#    'MCI': 'Assault',
#    'Division': 'D31',
#    'Hood_ID': 25,
#    'Neighbourhood': 'Glenfield-Jane Heights (25)',
#    'Lat': 43.7393913,
#    'Long': -79.5132217,
#    'FID': 365},
#   'geometry': {'x': -79.5132217, 'y': 43.73939130000001}},
#  {'attributes': {'Index_': 804,
#    'event_unique_id': 'GO-20141419195',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 13,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 13,
#    'MCI': 'Assault',
#    'Division': 'D55',
#    'Hood_ID': 65,
#    'Neighbourhood': 'Greenwood-Coxwell (65)',
#    'Lat': 43.6720848,
#    'Long': -79.3229141,
#    'FID': 436},
#   'geometry': {'x': -79.32291410000002, 'y': 43.67208480000001}},
#  {'attributes': {'Index_': 711,
#    'event_unique_id': 'GO-20141413929',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1420,
#    'ucr_ext': 100,
#    'offence': 'Assault With Weapon',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 14,
#    'MCI': 'Assault',
#    'Division': 'D11',
#    'Hood_ID': 93,
#    'Neighbourhood': 'Dovercourt-Wallace Emerson-Junction (93)',
#    'Lat': 43.6633987,
#    'Long': -79.4392929,
#    'FID': 437},
#   'geometry': {'x': -79.43929290000001, 'y': 43.6633987}},
#  {'attributes': {'Index_': 805,
#    'event_unique_id': 'GO-20141421820',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 21,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 11,
#    'MCI': 'Break and Enter',
#    'Division': 'D23',
#    'Hood_ID': 8,
#    'Neighbourhood': 'Humber Heights-Westmount (8)',
#    'Lat': 43.6876144,
#    'Long': -79.5226059,
#    'FID': 520},
#   'geometry': {'x': -79.5226059, 'y': 43.6876144}},
#  {'attributes': {'Index_': 712,
#    'event_unique_id': 'GO-20141414053',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Other',
#    'ucr_code': 1610,
#    'ucr_ext': 200,
#    'offence': 'Robbery - Mugging',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 14,
#    'MCI': 'Robbery',
#    'Division': 'D43',
#    'Hood_ID': 137,
#    'Neighbourhood': 'Woburn (137)',
#    'Lat': 43.7577248,
#    'Long': -79.2352676,
#    'FID': 522},
#   'geometry': {'x': -79.2352676, 'y': 43.75772479999999}},
#  {'attributes': {'Index_': 806,
#    'event_unique_id': 'GO-20141421589',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'Commercial',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 21,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 21,
#    'MCI': 'Assault',
#    'Division': 'D53',
#    'Hood_ID': 104,
#    'Neighbourhood': 'Mount Pleasant West (104)',
#    'Lat': 43.7082138,
#    'Long': -79.3986816,
#    'FID': 524},
#   'geometry': {'x': -79.3986816, 'y': 43.708213799999996}},
#  {'attributes': {'Index_': 713,
#    'event_unique_id': 'GO-20141414588',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Other',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 12,
#    'MCI': 'Assault',
#    'Division': 'D54',
#    'Hood_ID': 66,
#    'Neighbourhood': 'Danforth (66)',
#    'Lat': 43.6796799,
#    'Long': -79.3451538,
#    'FID': 527},
#   'geometry': {'x': -79.34515380000002, 'y': 43.6796799}},
#  {'attributes': {'Index_': 807,
#    'event_unique_id': 'GO-20141421281',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'Outside',
#    'ucr_code': 1610,
#    'ucr_ext': 180,
#    'offence': 'Robbery - Swarming',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 20,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 20,
#    'MCI': 'Robbery',
#    'Division': 'D32',
#    'Hood_ID': 32,
#    'Neighbourhood': 'Englemount-Lawrence (32)',
#    'Lat': 43.7290611,
#    'Long': -79.4459915,
#    'FID': 528},
#   'geometry': {'x': -79.4459915, 'y': 43.72906109999999}},
#  {'attributes': {'Index_': 714,
#    'event_unique_id': 'GO-20141414905',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Other',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 18,
#    'MCI': 'Assault',
#    'Division': 'D14',
#    'Hood_ID': 81,
#    'Neighbourhood': 'Trinity-Bellwoods (81)',
#    'Lat': 43.644207,
#    'Long': -79.4188614,
#    'FID': 532},
#   'geometry': {'x': -79.4188614, 'y': 43.644207}},
#  {'attributes': {'Index_': 808,
#    'event_unique_id': 'GO-20141421603',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 23,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 9,
#    'MCI': 'Break and Enter',
#    'Division': 'D32',
#    'Hood_ID': 36,
#    'Neighbourhood': 'Newtonbrook West (36)',
#    'Lat': 43.7784233,
#    'Long': -79.4216156,
#    'FID': 533},
#   'geometry': {'x': -79.42161559999998, 'y': 43.77842329999999}},
#  {'attributes': {'Index_': 809,
#    'event_unique_id': 'GO-20141420255',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'Other',
#    'ucr_code': 1610,
#    'ucr_ext': 200,
#    'offence': 'Robbery - Mugging',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 16,
#    'MCI': 'Robbery',
#    'Division': 'D53',
#    'Hood_ID': 104,
#    'Neighbourhood': 'Mount Pleasant West (104)',
#    'Lat': 43.7095871,
#    'Long': -79.3989944,
#    'FID': 534},
#   'geometry': {'x': -79.3989944, 'y': 43.7095871}},
#  {'attributes': {'Index_': 810,
#    'event_unique_id': 'GO-20141420765',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 18,
#    'MCI': 'Assault',
#    'Division': 'D41',
#    'Hood_ID': 124,
#    'Neighbourhood': 'Kennedy Park (124)',
#    'Lat': 43.7208672,
#    'Long': -79.2570877,
#    'FID': 535},
#   'geometry': {'x': -79.25708769999999, 'y': 43.72086720000001}},
#  {'attributes': {'Index_': 811,
#    'event_unique_id': 'GO-20141421698',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'Commercial',
#    'ucr_code': 1610,
#    'ucr_ext': 150,
#    'offence': 'Robbery - Purse Snatch',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 21,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 21,
#    'MCI': 'Robbery',
#    'Division': 'D23',
#    'Hood_ID': 3,
#    'Neighbourhood': 'Thistletown-Beaumond Heights (3)',
#    'Lat': 43.7372398,
#    'Long': -79.5653076,
#    'FID': 536},
#   'geometry': {'x': -79.5653076, 'y': 43.73723979999999}},
#  {'attributes': {'Index_': 812,
#    'event_unique_id': 'GO-20141421855',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 22,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 22,
#    'MCI': 'Break and Enter',
#    'Division': 'D41',
#    'Hood_ID': 125,
#    'Neighbourhood': 'Ionview (125)',
#    'Lat': 43.7287025,
#    'Long': -79.2717514,
#    'FID': 537},
#   'geometry': {'x': -79.27175140000001, 'y': 43.7287025}},
#  {'attributes': {'Index_': 813,
#    'event_unique_id': 'GO-2015170210',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1422507600000,
#    'premisetype': 'Commercial',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2015,
#    'reportedmonth': 'January',
#    'reportedday': 29,
#    'reporteddayofyear': 29,
#    'reporteddayofweek': 'Thursday  ',
#    'reportedhour': 15,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 22,
#    'MCI': 'Assault',
#    'Division': 'D32',
#    'Hood_ID': 34,
#    'Neighbourhood': 'Bathurst Manor (34)',
#    'Lat': 43.783844,
#    'Long': -79.4701462,
#    'FID': 538},
#   'geometry': {'x': -79.4701462, 'y': 43.783843999999995}},
#  {'attributes': {'Index_': 814,
#    'event_unique_id': 'GO-20141439927',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1391058000000,
#    'premisetype': 'Other',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 30,
#    'reporteddayofyear': 30,
#    'reporteddayofweek': 'Thursday  ',
#    'reportedhour': 22,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 7,
#    'MCI': 'Assault',
#    'Division': 'D55',
#    'Hood_ID': 63,
#    'Neighbourhood': 'The Beaches (63)',
#    'Lat': 43.6592369,
#    'Long': -79.3284378,
#    'FID': 539},
#   'geometry': {'x': -79.3284378, 'y': 43.6592369}},
#  {'attributes': {'Index_': 815,
#    'event_unique_id': 'GO-20141432868',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390971600000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 29,
#    'reporteddayofyear': 29,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 17,
#    'MCI': 'Assault',
#    'Division': 'D42',
#    'Hood_ID': 130,
#    'Neighbourhood': 'Milliken (130)',
#    'Lat': 43.819912,
#    'Long': -79.2872849,
#    'FID': 540},
#   'geometry': {'x': -79.28728490000002, 'y': 43.819911999999995}},
#  {'attributes': {'Index_': 816,
#    'event_unique_id': 'GO-20141424109',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390885200000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 28,
#    'reporteddayofyear': 28,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 11,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 18,
#    'MCI': 'Assault',
#    'Division': 'D22',
#    'Hood_ID': 18,
#    'Neighbourhood': 'New Toronto (18)',
#    'Lat': 43.5974464,
#    'Long': -79.5202408,
#    'FID': 541},
#   'geometry': {'x': -79.52024080000001, 'y': 43.597446399999995}},
#  {'attributes': {'Index_': 817,
#    'event_unique_id': 'GO-20141424403',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390885200000,
#    'premisetype': 'Other',
#    'ucr_code': 2132,
#    'ucr_ext': 200,
#    'offence': 'Theft From Motor Vehicle Over',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 28,
#    'reporteddayofyear': 28,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 14,
#    'MCI': 'Theft Over',
#    'Division': 'D23    ',
#    'Hood_ID': 1,
#    'Neighbourhood': 'West Humber-Clairville (1)',
#    'Lat': 43.7019501,
#    'Long': -79.5756302,
#    'FID': 542},
#   'geometry': {'x': -79.5756302, 'y': 43.70195009999998}},
#  {'attributes': {'Index_': 818,
#    'event_unique_id': 'GO-20141425675',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390885200000,
#    'premisetype': 'Other',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 28,
#    'reporteddayofyear': 28,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 15,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 21,
#    'MCI': 'Assault',
#    'Division': 'D32',
#    'Hood_ID': 32,
#    'Neighbourhood': 'Englemount-Lawrence (32)',
#    'Lat': 43.7194862,
#    'Long': -79.4439087,
#    'FID': 543},
#   'geometry': {'x': -79.44390870000001, 'y': 43.71948619999999}},
#  {'attributes': {'Index_': 819,
#    'event_unique_id': 'GO-20141425675',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390885200000,
#    'premisetype': 'Other',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 28,
#    'reporteddayofyear': 28,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 15,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 21,
#    'MCI': 'Assault',
#    'Division': 'D32',
#    'Hood_ID': 32,
#    'Neighbourhood': 'Englemount-Lawrence (32)',
#    'Lat': 43.7194862,
#    'Long': -79.4439087,
#    'FID': 544},
#   'geometry': {'x': -79.44390870000001, 'y': 43.71948619999999}},
#  {'attributes': {'Index_': 820,
#    'event_unique_id': 'GO-20141422185',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390885200000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 28,
#    'reporteddayofyear': 28,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 0,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 19,
#    'MCI': 'Assault',
#    'Division': 'D41',
#    'Hood_ID': 119,
#    'Neighbourhood': 'Wexford/Maryvale (119)',
#    'Lat': 43.7303886,
#    'Long': -79.3050003,
#    'FID': 545},
#   'geometry': {'x': -79.3050003, 'y': 43.7303886}},
#  {'attributes': {'Index_': 821,
#    'event_unique_id': 'GO-20141426909',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390885200000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 220,
#    'offence': "B&E W'Intent",
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 28,
#    'reporteddayofyear': 28,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 16,
#    'MCI': 'Break and Enter',
#    'Division': 'D31',
#    'Hood_ID': 26,
#    'Neighbourhood': 'Downsview-Roding-CFB (26)',
#    'Lat': 43.7339935,
#    'Long': -79.4794998,
#    'FID': 546},
#   'geometry': {'x': -79.47949980000001, 'y': 43.73399349999999}},
#  {'attributes': {'Index_': 822,
#    'event_unique_id': 'GO-20141421787',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1390885200000,
#    'premisetype': 'Apartment',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 28,
#    'reporteddayofyear': 28,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 7,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 16,
#    'MCI': 'Break and Enter',
#    'Division': 'D51',
#    'Hood_ID': 71,
#    'Neighbourhood': 'Cabbagetown-South St.James Town (71)',
#    'Lat': 43.6624222,
#    'Long': -79.3767166,
#    'FID': 547},
#   'geometry': {'x': -79.3767166, 'y': 43.6624222}},
#  {'attributes': {'Index_': 823,
#    'event_unique_id': 'GO-20141908267',
#    'occurrencedate': 1390798800000,
#    'reporteddate': 1397707200000,
#    'premisetype': 'Outside',
#    'ucr_code': 1610,
#    'ucr_ext': 220,
#    'offence': 'Robbery - Other',
#    'reportedyear': 2014,
#    'reportedmonth': 'April',
#    'reportedday': 17,
#    'reporteddayofyear': 107,
#    'reporteddayofweek': 'Thursday  ',
#    'reportedhour': 11,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 27,
#    'occurrencedayofyear': 27,
#    'occurrencedayofweek': 'Monday    ',
#    'occurrencehour': 15,
#    'MCI': 'Robbery',
#    'Division': 'D52',
#    'Hood_ID': 76,
#    'Neighbourhood': 'Bay Street Corridor (76)',
#    'Lat': 43.6505699,
#    'Long': -79.381073,
#    'FID': 548},
#   'geometry': {'x': -79.381073, 'y': 43.650569899999994}},
#  {'attributes': {'Index_': 715,
#    'event_unique_id': 'GO-20141415009',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 18,
#    'MCI': 'Assault',
#    'Division': 'D23',
#    'Hood_ID': 2,
#    'Neighbourhood': 'Mount Olive-Silverstone-Jamestown (2)',
#    'Lat': 43.7419281,
#    'Long': -79.5942078,
#    'FID': 629},
#   'geometry': {'x': -79.5942078, 'y': 43.741928099999996}},
#  {'attributes': {'Index_': 716,
#    'event_unique_id': 'GO-20141415932',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 23,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 22,
#    'MCI': 'Assault',
#    'Division': 'D53',
#    'Hood_ID': 102,
#    'Neighbourhood': 'Forest Hill North (102)',
#    'Lat': 43.7056847,
#    'Long': -79.4239883,
#    'FID': 631},
#   'geometry': {'x': -79.4239883, 'y': 43.70568469999999}},
#  {'attributes': {'Index_': 717,
#    'event_unique_id': 'GO-20141415932',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 23,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 22,
#    'MCI': 'Assault',
#    'Division': 'D53',
#    'Hood_ID': 102,
#    'Neighbourhood': 'Forest Hill North (102)',
#    'Lat': 43.7056847,
#    'Long': -79.4239883,
#    'FID': 633},
#   'geometry': {'x': -79.4239883, 'y': 43.70568469999999}},
#  {'attributes': {'Index_': 718,
#    'event_unique_id': 'GO-20141415878',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 23,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 22,
#    'MCI': 'Assault',
#    'Division': 'D42',
#    'Hood_ID': 129,
#    'Neighbourhood': 'Agincourt North (129)',
#    'Lat': 43.7990837,
#    'Long': -79.2642593,
#    'FID': 636},
#   'geometry': {'x': -79.2642593, 'y': 43.79908369999998}},
#  {'attributes': {'Index_': 719,
#    'event_unique_id': 'GO-20141419724',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390798800000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 27,
#    'reporteddayofyear': 27,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 3,
#    'MCI': 'Assault',
#    'Division': 'D42',
#    'Hood_ID': 117,
#    'Neighbourhood': "L'Amoreaux (117)",
#    'Lat': 43.7996597,
#    'Long': -79.2924576,
#    'FID': 640},
#   'geometry': {'x': -79.2924576, 'y': 43.7996597}},
#  {'attributes': {'Index_': 720,
#    'event_unique_id': 'GO-20141414104',
#    'occurrencedate': 1390712400000,
#    'reporteddate': 1390712400000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 26,
#    'reporteddayofyear': 26,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 26,
#    'occurrencedayofyear': 26,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 15,
#    'MCI': 'Assault',
#    'Division': 'D11',
#    'Hood_ID': 93,
#    'Neighbourhood': 'Dovercourt-Wallace Emerson-Junction (93)',
#    'Lat': 43.6610718,
#    'Long': -79.4416504,
#    'FID': 644},
#   'geometry': {'x': -79.44165040000001, 'y': 43.661071799999995}},
#  {'attributes': {'Index_': 976,
#    'event_unique_id': 'GO-2015942420',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1433476800000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2015,
#    'reportedmonth': 'June',
#    'reportedday': 5,
#    'reporteddayofyear': 156,
#    'reporteddayofweek': 'Friday    ',
#    'reportedhour': 15,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D14',
#    'Hood_ID': 84,
#    'Neighbourhood': 'Little Portugal (84)',
#    'Lat': 43.651516,
#    'Long': -79.42659,
#    'FID': 713},
#   'geometry': {'x': -79.42659000000002, 'y': 43.651515999999994}},
#  {'attributes': {'Index_': 977,
#    'event_unique_id': 'GO-20162295518',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1482901200000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2016,
#    'reportedmonth': 'December',
#    'reportedday': 28,
#    'reporteddayofyear': 363,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D31',
#    'Hood_ID': 25,
#    'Neighbourhood': 'Glenfield-Jane Heights (25)',
#    'Lat': 43.7544861,
#    'Long': -79.5181274,
#    'FID': 714},
#   'geometry': {'x': -79.5181274, 'y': 43.754486099999994}},
#  {'attributes': {'Index_': 978,
#    'event_unique_id': 'GO-20142458487',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1404792000000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'July',
#    'reportedday': 8,
#    'reporteddayofyear': 189,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 21,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D51',
#    'Hood_ID': 71,
#    'Neighbourhood': 'Cabbagetown-South St.James Town (71)',
#    'Lat': 43.6702614,
#    'Long': -79.3704071,
#    'FID': 715},
#   'geometry': {'x': -79.3704071, 'y': 43.67026139999999}},
#  {'attributes': {'Index_': 979,
#    'event_unique_id': 'GO-20142458487',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1404792000000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'July',
#    'reportedday': 8,
#    'reporteddayofyear': 189,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 21,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D51',
#    'Hood_ID': 71,
#    'Neighbourhood': 'Cabbagetown-South St.James Town (71)',
#    'Lat': 43.6702614,
#    'Long': -79.3704071,
#    'FID': 716},
#   'geometry': {'x': -79.3704071, 'y': 43.67026139999999}},
#  {'attributes': {'Index_': 980,
#    'event_unique_id': 'GO-20141573896',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1392958800000,
#    'premisetype': 'House',
#    'ucr_code': 2130,
#    'ucr_ext': 210,
#    'offence': 'Theft Over',
#    'reportedyear': 2014,
#    'reportedmonth': 'February',
#    'reportedday': 21,
#    'reporteddayofyear': 52,
#    'reporteddayofweek': 'Friday    ',
#    'reportedhour': 22,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Theft Over',
#    'Division': 'D54',
#    'Hood_ID': 58,
#    'Neighbourhood': 'Old East York (58)',
#    'Lat': 43.6933403,
#    'Long': -79.3448105,
#    'FID': 717},
#   'geometry': {'x': -79.3448105, 'y': 43.69334030000001}},
#  {'attributes': {'Index_': 981,
#    'event_unique_id': 'GO-20143372895',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1418274000000,
#    'premisetype': 'House',
#    'ucr_code': 2130,
#    'ucr_ext': 210,
#    'offence': 'Theft Over',
#    'reportedyear': 2014,
#    'reportedmonth': 'December',
#    'reportedday': 11,
#    'reporteddayofyear': 345,
#    'reporteddayofweek': 'Thursday  ',
#    'reportedhour': 0,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Theft Over',
#    'Division': 'D22',
#    'Hood_ID': 16,
#    'Neighbourhood': 'Stonegate-Queensway (16)',
#    'Lat': 43.6435776,
#    'Long': -79.5000839,
#    'FID': 718},
#   'geometry': {'x': -79.5000839, 'y': 43.6435776}},
#  {'attributes': {'Index_': 982,
#    'event_unique_id': 'GO-20142248243',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1402200000000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1420,
#    'ucr_ext': 110,
#    'offence': 'Assault Bodily Harm',
#    'reportedyear': 2014,
#    'reportedmonth': 'June',
#    'reportedday': 8,
#    'reporteddayofyear': 159,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 16,
#    'MCI': 'Assault',
#    'Division': 'D31',
#    'Hood_ID': 24,
#    'Neighbourhood': 'Black Creek (24)',
#    'Lat': 43.7590179,
#    'Long': -79.5177765,
#    'FID': 719},
#   'geometry': {'x': -79.5177765, 'y': 43.759017899999996}},
#  {'attributes': {'Index_': 983,
#    'event_unique_id': 'GO-20142248243',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1402200000000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1420,
#    'ucr_ext': 100,
#    'offence': 'Assault With Weapon',
#    'reportedyear': 2014,
#    'reportedmonth': 'June',
#    'reportedday': 8,
#    'reporteddayofyear': 159,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 16,
#    'MCI': 'Assault',
#    'Division': 'D31',
#    'Hood_ID': 24,
#    'Neighbourhood': 'Black Creek (24)',
#    'Lat': 43.7590179,
#    'Long': -79.5177765,
#    'FID': 720},
#   'geometry': {'x': -79.5177765, 'y': 43.759017899999996}},
#  {'attributes': {'Index_': 984,
#    'event_unique_id': 'GO-20142261574',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1402372800000,
#    'premisetype': 'Commercial',
#    'ucr_code': 2130,
#    'ucr_ext': 210,
#    'offence': 'Theft Over',
#    'reportedyear': 2014,
#    'reportedmonth': 'June',
#    'reportedday': 10,
#    'reporteddayofyear': 161,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 9,
#    'MCI': 'Theft Over',
#    'Division': 'D42',
#    'Hood_ID': 132,
#    'Neighbourhood': 'Malvern (132)',
#    'Lat': 43.8080482,
#    'Long': -79.2341995,
#    'FID': 721},
#   'geometry': {'x': -79.2341995, 'y': 43.80804820000001}},
#  {'attributes': {'Index_': 985,
#    'event_unique_id': 'GO-20142457130',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1404792000000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'July',
#    'reportedday': 8,
#    'reporteddayofyear': 189,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 17,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D43',
#    'Hood_ID': 136,
#    'Neighbourhood': 'West Hill (136)',
#    'Lat': 43.7664986,
#    'Long': -79.1948929,
#    'FID': 722},
#   'geometry': {'x': -79.19489289999999, 'y': 43.76649859999999}},
#  {'attributes': {'Index_': 986,
#    'event_unique_id': 'GO-20151639373',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1442894400000,
#    'premisetype': 'Outside',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2015,
#    'reportedmonth': 'September',
#    'reportedday': 22,
#    'reporteddayofyear': 265,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D42',
#    'Hood_ID': 129,
#    'Neighbourhood': 'Agincourt North (129)',
#    'Lat': 43.8071899,
#    'Long': -79.2703934,
#    'FID': 723},
#   'geometry': {'x': -79.2703934, 'y': 43.8071899}},
#  {'attributes': {'Index_': 987,
#    'event_unique_id': 'GO-20151639373',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1442894400000,
#    'premisetype': 'Outside',
#    'ucr_code': 1420,
#    'ucr_ext': 100,
#    'offence': 'Assault With Weapon',
#    'reportedyear': 2015,
#    'reportedmonth': 'September',
#    'reportedday': 22,
#    'reporteddayofyear': 265,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D42',
#    'Hood_ID': 129,
#    'Neighbourhood': 'Agincourt North (129)',
#    'Lat': 43.8071899,
#    'Long': -79.2703934,
#    'FID': 724},
#   'geometry': {'x': -79.2703934, 'y': 43.8071899}},
#  {'attributes': {'Index_': 988,
#    'event_unique_id': 'GO-20161572759',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1472961600000,
#    'premisetype': 'Outside',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2016,
#    'reportedmonth': 'September',
#    'reportedday': 4,
#    'reporteddayofyear': 248,
#    'reporteddayofweek': 'Sunday    ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 0,
#    'MCI': 'Assault',
#    'Division': 'D43',
#    'Hood_ID': 136,
#    'Neighbourhood': 'West Hill (136)',
#    'Lat': 43.7711601,
#    'Long': -79.1739273,
#    'FID': 725},
#   'geometry': {'x': -79.1739273, 'y': 43.771160099999996}},
#  {'attributes': {'Index_': 989,
#    'event_unique_id': 'GO-20151006208',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1434340800000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2015,
#    'reportedmonth': 'June',
#    'reportedday': 15,
#    'reporteddayofyear': 166,
#    'reporteddayofweek': 'Monday    ',
#    'reportedhour': 18,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 18,
#    'MCI': 'Assault',
#    'Division': 'D43',
#    'Hood_ID': 137,
#    'Neighbourhood': 'Woburn (137)',
#    'Lat': 43.7566643,
#    'Long': -79.2401886,
#    'FID': 726},
#   'geometry': {'x': -79.2401886, 'y': 43.75666429999998}},
#  {'attributes': {'Index_': 990,
#    'event_unique_id': 'GO-20141488291',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1391749200000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'February',
#    'reportedday': 7,
#    'reporteddayofyear': 38,
#    'reporteddayofweek': 'Friday    ',
#    'reportedhour': 19,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 10,
#    'MCI': 'Assault',
#    'Division': 'D32',
#    'Hood_ID': 34,
#    'Neighbourhood': 'Bathurst Manor (34)',
#    'Lat': 43.770256,
#    'Long': -79.4607239,
#    'FID': 727},
#   'geometry': {'x': -79.4607239, 'y': 43.770255999999996}},
#  {'attributes': {'Index_': 991,
#    'event_unique_id': 'GO-20141277440',
#    'occurrencedate': 1388552400000,
#    'reporteddate': 1388811600000,
#    'premisetype': 'Outside',
#    'ucr_code': 2132,
#    'ucr_ext': 200,
#    'offence': 'Theft From Motor Vehicle Over',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 4,
#    'reporteddayofyear': 4,
#    'reporteddayofweek': 'Saturday  ',
#    'reportedhour': 0,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 1,
#    'occurrencedayofyear': 1,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 2,
#    'MCI': 'Theft Over',
#    'Division': 'D14',
#    'Hood_ID': 80,
#    'Neighbourhood': 'Palmerston-Little Italy (80)',
#    'Lat': 43.654911,
#    'Long': -79.4202728,
# ...
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 23,
#    'MCI': 'Break and Enter',
#    'Division': 'D42',
#    'Hood_ID': 128,
#    'Neighbourhood': 'Agincourt South-Malvern West (128)',
#    'Lat': 43.7853508,
#    'Long': -79.2785721,
#    'FID': 2125},
#   'geometry': {'x': -79.2785721, 'y': 43.7853508}},
#  {'attributes': {'Index_': 2622,
#    'event_unique_id': 'GO-20141381945',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'Commercial',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 1,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 1,
#    'MCI': 'Break and Enter',
#    'Division': 'D14',
#    'Hood_ID': 77,
#    'Neighbourhood': 'Waterfront Communities-The Island (77)',
#    'Lat': 43.6444244,
#    'Long': -79.3946228,
#    'FID': 2126},
#   'geometry': {'x': -79.3946228, 'y': 43.6444244}},
#  {'attributes': {'Index_': 2623,
#    'event_unique_id': 'GO-20141385366',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1610,
#    'ucr_ext': 180,
#    'offence': 'Robbery - Swarming',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 15,
#    'MCI': 'Robbery',
#    'Division': 'D41',
#    'Hood_ID': 120,
#    'Neighbourhood': 'Clairlea-Birchmount (120)',
#    'Lat': 43.7054405,
#    'Long': -79.2675018,
#    'FID': 2127},
#   'geometry': {'x': -79.2675018, 'y': 43.705440499999995}},
#  {'attributes': {'Index_': 2624,
#    'event_unique_id': 'GO-20141385366',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1610,
#    'ucr_ext': 220,
#    'offence': 'Robbery - Other',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 15,
#    'MCI': 'Robbery',
#    'Division': 'D41',
#    'Hood_ID': 120,
#    'Neighbourhood': 'Clairlea-Birchmount (120)',
#    'Lat': 43.7054405,
#    'Long': -79.2675018,
#    'FID': 2128},
#   'geometry': {'x': -79.2675018, 'y': 43.705440499999995}},
#  {'attributes': {'Index_': 2625,
#    'event_unique_id': 'GO-20141385366',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1610,
#    'ucr_ext': 220,
#    'offence': 'Robbery - Other',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 15,
#    'MCI': 'Robbery',
#    'Division': 'D41',
#    'Hood_ID': 120,
#    'Neighbourhood': 'Clairlea-Birchmount (120)',
#    'Lat': 43.7054405,
#    'Long': -79.2675018,
#    'FID': 2129},
#   'geometry': {'x': -79.2675018, 'y': 43.705440499999995}},
#  {'attributes': {'Index_': 2626,
#    'event_unique_id': 'GO-20141385341',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 14,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 8,
#    'MCI': 'Break and Enter',
#    'Division': 'D11',
#    'Hood_ID': 89,
#    'Neighbourhood': 'Runnymede-Bloor West Village (89)',
#    'Lat': 43.6564369,
#    'Long': -79.4839172,
#    'FID': 2130},
#   'geometry': {'x': -79.4839172, 'y': 43.656436899999996}},
#  {'attributes': {'Index_': 2627,
#    'event_unique_id': 'GO-20141383801',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 11,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 10,
#    'MCI': 'Break and Enter',
#    'Division': 'D32',
#    'Hood_ID': 37,
#    'Neighbourhood': 'Willowdale West (37)',
#    'Lat': 43.7699203,
#    'Long': -79.4293289,
#    'FID': 2131},
#   'geometry': {'x': -79.4293289, 'y': 43.76992030000001}},
#  {'attributes': {'Index_': 2628,
#    'event_unique_id': 'GO-20141387280',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'House',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 22,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 22,
#    'MCI': 'Assault',
#    'Division': 'D13',
#    'Hood_ID': 107,
#    'Neighbourhood': 'Oakwood Village (107)',
#    'Lat': 43.6865082,
#    'Long': -79.4416199,
#    'FID': 2132},
#   'geometry': {'x': -79.4416199, 'y': 43.686508199999984}},
#  {'attributes': {'Index_': 2629,
#    'event_unique_id': 'GO-20141386463',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 19,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 19,
#    'MCI': 'Break and Enter',
#    'Division': 'D33',
#    'Hood_ID': 40,
#    'Neighbourhood': 'St.Andrew-Windfields (40)',
#    'Lat': 43.7628059,
#    'Long': -79.38414,
#    'FID': 2133},
#   'geometry': {'x': -79.38414, 'y': 43.7628059}},
#  {'attributes': {'Index_': 2630,
#    'event_unique_id': 'GO-20141386816',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390280400000,
#    'premisetype': 'Apartment',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 21,
#    'reporteddayofyear': 21,
#    'reporteddayofweek': 'Tuesday   ',
#    'reportedhour': 20,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 18,
#    'MCI': 'Break and Enter',
#    'Division': 'D43',
#    'Hood_ID': 123,
#    'Neighbourhood': 'Cliffcrest (123)',
#    'Lat': 43.7227173,
#    'Long': -79.235199,
#    'FID': 2134},
#   'geometry': {'x': -79.235199, 'y': 43.7227173}},
#  {'attributes': {'Index_': 2631,
#    'event_unique_id': 'GO-20141389773',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1390366800000,
#    'premisetype': 'Other',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 22,
#    'reporteddayofyear': 22,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 11,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 15,
#    'MCI': 'Assault',
#    'Division': 'D14',
#    'Hood_ID': 85,
#    'Neighbourhood': 'South Parkdale (85)',
#    'Lat': 43.6374626,
#    'Long': -79.4347229,
#    'FID': 2135},
#   'geometry': {'x': -79.4347229, 'y': 43.63746259999999}},
#  {'attributes': {'Index_': 2632,
#    'event_unique_id': 'GO-20141613823',
#    'occurrencedate': 1390280400000,
#    'reporteddate': 1393563600000,
#    'premisetype': 'Commercial',
#    'ucr_code': 2130,
#    'ucr_ext': 200,
#    'offence': 'Theft From Mail / Bag / Key',
#    'reportedyear': 2014,
#    'reportedmonth': 'February',
#    'reportedday': 28,
#    'reporteddayofyear': 59,
#    'reporteddayofweek': 'Friday    ',
#    'reportedhour': 15,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 21,
#    'occurrencedayofyear': 21,
#    'occurrencedayofweek': 'Tuesday   ',
#    'occurrencehour': 8,
#    'MCI': 'Theft Over',
#    'Division': 'D52',
#    'Hood_ID': 76,
#    'Neighbourhood': 'Bay Street Corridor (76)',
#    'Lat': 43.6498947,
#    'Long': -79.380806,
#    'FID': 2136},
#   'geometry': {'x': -79.380806, 'y': 43.64989469999999}},
#  {'attributes': {'Index_': 2202,
#    'event_unique_id': 'GO-20141429936',
#    'occurrencedate': 1390107600000,
#    'reporteddate': 1390971600000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 29,
#    'reporteddayofyear': 29,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 12,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 19,
#    'occurrencedayofyear': 19,
#    'occurrencedayofweek': 'Sunday    ',
#    'occurrencehour': 22,
#    'MCI': 'Assault',
#    'Division': 'D13',
#    'Hood_ID': 108,
#    'Neighbourhood': 'Briar Hill-Belgravia (108)',
#    'Lat': 43.7022552,
#    'Long': -79.4411087,
#    'FID': 2137},
#   'geometry': {'x': -79.4411087, 'y': 43.70225519999999}},
#  {'attributes': {'Index_': 2702,
#    'event_unique_id': 'GO-20141403470',
#    'occurrencedate': 1390539600000,
#    'reporteddate': 1390539600000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 24,
#    'reporteddayofyear': 24,
#    'reporteddayofweek': 'Friday    ',
#    'reportedhour': 16,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 24,
#    'occurrencedayofyear': 24,
#    'occurrencedayofweek': 'Friday    ',
#    'occurrencehour': 16,
#    'MCI': 'Break and Enter',
#    'Division': 'D42',
#    'Hood_ID': 117,
#    'Neighbourhood': "L'Amoreaux (117)",
#    'Lat': 43.7977409,
#    'Long': -79.3016815,
#    'FID': 2138},
#   'geometry': {'x': -79.3016815, 'y': 43.7977409}},
#  {'attributes': {'Index_': 2633,
#    'event_unique_id': 'GO-20141390289',
#    'occurrencedate': 1390366800000,
#    'reporteddate': 1390366800000,
#    'premisetype': 'Commercial',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 22,
#    'reporteddayofyear': 22,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 15,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 22,
#    'occurrencedayofyear': 22,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 12,
#    'MCI': 'Assault',
#    'Division': 'D53',
#    'Hood_ID': 104,
#    'Neighbourhood': 'Mount Pleasant West (104)',
#    'Lat': 43.7067337,
#    'Long': -79.3983688,
#    'FID': 2140},
#   'geometry': {'x': -79.39836880000001, 'y': 43.706733699999994}},
#  {'attributes': {'Index_': 2634,
#    'event_unique_id': 'GO-20141391884',
#    'occurrencedate': 1390366800000,
#    'reporteddate': 1390366800000,
#    'premisetype': 'Other',
#    'ucr_code': 1610,
#    'ucr_ext': 100,
#    'offence': 'Robbery With Weapon',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 22,
#    'reporteddayofyear': 22,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 17,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 22,
#    'occurrencedayofyear': 22,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 17,
#    'MCI': 'Robbery',
#    'Division': 'D23',
#    'Hood_ID': 3,
#    'Neighbourhood': 'Thistletown-Beaumond Heights (3)',
#    'Lat': 43.742466,
#    'Long': -79.567749,
#    'FID': 2141},
#   'geometry': {'x': -79.567749, 'y': 43.74246599999998}},
#  {'attributes': {'Index_': 2635,
#    'event_unique_id': 'GO-20141391769',
#    'occurrencedate': 1390366800000,
#    'reporteddate': 1390366800000,
#    'premisetype': 'House',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 22,
#    'reporteddayofyear': 22,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 21,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 22,
#    'occurrencedayofyear': 22,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 8,
#    'MCI': 'Break and Enter',
#    'Division': 'D42',
#    'Hood_ID': 116,
#    'Neighbourhood': 'Steeles (116)',
#    'Lat': 43.8200912,
#    'Long': -79.3187027,
#    'FID': 2142},
#   'geometry': {'x': -79.31870270000002, 'y': 43.8200912}},
#  {'attributes': {'Index_': 2636,
#    'event_unique_id': 'GO-20141392449',
#    'occurrencedate': 1390366800000,
#    'reporteddate': 1390366800000,
#    'premisetype': 'Commercial',
#    'ucr_code': 2120,
#    'ucr_ext': 200,
#    'offence': 'B&E',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 22,
#    'reporteddayofyear': 22,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 19,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 22,
#    'occurrencedayofyear': 22,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 18,
#    'MCI': 'Break and Enter',
#    'Division': 'D52',
#    'Hood_ID': 77,
#    'Neighbourhood': 'Waterfront Communities-The Island (77)',
#    'Lat': 43.648201,
#    'Long': -79.3886795,
#    'FID': 2143},
#   'geometry': {'x': -79.3886795, 'y': 43.648200999999986}},
#  {'attributes': {'Index_': 2637,
#    'event_unique_id': 'GO-20141387835',
#    'occurrencedate': 1390366800000,
#    'reporteddate': 1390366800000,
#    'premisetype': 'Apartment',
#    'ucr_code': 1420,
#    'ucr_ext': 100,
#    'offence': 'Assault With Weapon',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 22,
#    'reporteddayofyear': 22,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 2,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 22,
#    'occurrencedayofyear': 22,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 2,
#    'MCI': 'Assault',
#    'Division': 'D22',
#    'Hood_ID': 17,
#    'Neighbourhood': 'Mimico (includes Humber Bay Shores) (17)',
#    'Lat': 43.6129417,
#    'Long': -79.4933624,
#    'FID': 2144},
#   'geometry': {'x': -79.49336239999998, 'y': 43.6129417}},
#  {'attributes': {'Index_': 2638,
#    'event_unique_id': 'GO-20141391881',
#    'occurrencedate': 1390366800000,
#    'reporteddate': 1390366800000,
#    'premisetype': 'Other',
#    'ucr_code': 1430,
#    'ucr_ext': 100,
#    'offence': 'Assault',
#    'reportedyear': 2014,
#    'reportedmonth': 'January',
#    'reportedday': 22,
#    'reporteddayofyear': 22,
#    'reporteddayofweek': 'Wednesday ',
#    'reportedhour': 17,
#    'occurrenceyear': 2014,
#    'occurrencemonth': 'January',
#    'occurrenceday': 22,
#    'occurrencedayofyear': 22,
#    'occurrencedayofweek': 'Wednesday ',
#    'occurrencehour': 17,
#    'MCI': 'Assault',
#    'Division': 'D52',
#    'Hood_ID': 76,
#    'Neighbourhood': 'Bay Street Corridor (76)',
#    'Lat': 43.6459885,
#    'Long': -79.3791351,
#    'FID': 2145},
#   'geometry': {'x': -79.3791351, 'y': 43.645988499999994}},
#  ...]

# %%
len(mci_data['features'])
# Out:
# 2000

# %%
# 2000 but they should be ~131,000
# this api limits to 2000 records
# we'll loop per chunks of time to get all records

# %%
years = range(2014,2018)
daysofyear = range(1,365,10)

# %%
# Toronto police major crime indicator data:
mci_data=[]
for year in years:
    for day in daysofyear:
        clear_output(wait=True)
        
        response = requests.get('https://services.arcgis.com/S9th0jAJ7bqgIRjw/arcgis/rest/services/MCI_2014_2017/FeatureServer/0/query?where=occurrenceyear%20%3E%3D%20' + str(year) + '%20AND%20occurrenceyear%20%3C%3D%20' + str(year) + '%20AND%20occurrencedayofyear%20%3E%3D%20' + str(day) + '%20AND%20occurrencedayofyear%20%3C%3D%20' + str(day+10) + '&outFields=Index_,event_unique_id,occurrencedate,premisetype,offence,occurrenceyear,occurrencemonth,occurrenceday,occurrencedayofyear,occurrencedayofweek,occurrencehour,Hood_ID,Neighbourhood,MCI&outSR=4326&f=json').json()
        for record in response['features']:
            mci_data.append(record)
        
        # was taking a long time, found this way to show progress
        if (year == 2017 and day > 350):
            print( "Done")
        else:
            print( "fetching data for days " + str(day) + " to " + str(day+10) + " of year " + str(year) )
# Out:
# Done

# %%
len(mci_data)
# larger than expected, must have duplicates
# Out:
# 142983

# %%
crimes_df_raw = json_normalize(mci_data)
crimes_df_raw.head()
# Out:
#    attributes.Hood_ID  attributes.Index_ attributes.MCI  \
# 0                  84                976        Assault
# 1                  25                977        Assault
# 2                  71                978        Assault
# 3                  71                979        Assault
# 4                  58                980     Theft Over
#
#                attributes.Neighbourhood attributes.event_unique_id  \
# 0                  Little Portugal (84)              GO-2015942420
# 1           Glenfield-Jane Heights (25)             GO-20162295518
# 2  Cabbagetown-South St.James Town (71)             GO-20142458487
# 3  Cabbagetown-South St.James Town (71)             GO-20142458487
# 4                    Old East York (58)             GO-20141573896
#
#    attributes.occurrencedate  attributes.occurrenceday  \
# 0              1388552400000                         1
# 1              1388552400000                         1
# 2              1388552400000                         1
# 3              1388552400000                         1
# 4              1388552400000                         1
#
#   attributes.occurrencedayofweek  attributes.occurrencedayofyear  \
# 0                     Wednesday                                1
# 1                     Wednesday                                1
# 2                     Wednesday                                1
# 3                     Wednesday                                1
# 4                     Wednesday                                1
#
#    attributes.occurrencehour attributes.occurrencemonth  \
# 0                          0                    January
# 1                          0                    January
# 2                          0                    January
# 3                          0                    January
# 4                          0                    January
#
#    attributes.occurrenceyear attributes.offence attributes.premisetype  \
# 0                       2014            Assault              Apartment
# 1                       2014            Assault              Apartment
# 2                       2014            Assault              Apartment
# 3                       2014            Assault              Apartment
# 4                       2014         Theft Over                  House
#
#    geometry.x  geometry.y
# 0  -79.426590   43.651516
# 1  -79.518127   43.754486
# 2  -79.370407   43.670261
# 3  -79.370407   43.670261
# 4  -79.344810   43.693340

# %%
# remove extra columns
crimes_df = crimes_df_raw.drop(['geometry.x', 'geometry.y'], axis=1).drop_duplicates()

# %%
# remove 'attributes' from headers
crimes_df.columns = crimes_df.columns.str.strip().str.replace('attributes.','')
crimes_df.head()
# Out:
#    Hood_ID  Index_         MCI                         Neighbourhood  \
# 0       84     976     Assault                  Little Portugal (84)
# 1       25     977     Assault           Glenfield-Jane Heights (25)
# 2       71     978     Assault  Cabbagetown-South St.James Town (71)
# 3       71     979     Assault  Cabbagetown-South St.James Town (71)
# 4       58     980  Theft Over                    Old East York (58)
#
#   event_unique_id  occurrencedate  occurrenceday occurrencedayofweek  \
# 0   GO-2015942420   1388552400000              1          Wednesday
# 1  GO-20162295518   1388552400000              1          Wednesday
# 2  GO-20142458487   1388552400000              1          Wednesday
# 3  GO-20142458487   1388552400000              1          Wednesday
# 4  GO-20141573896   1388552400000              1          Wednesday
#
#    occurrencedayofyear  occurrencehour occurrencemonth  occurrenceyear  \
# 0                    1               0         January            2014
# 1                    1               0         January            2014
# 2                    1               0         January            2014
# 3                    1               0         January            2014
# 4                    1               0         January            2014
#
#       offence premisetype
# 0     Assault   Apartment
# 1     Assault   Apartment
# 2     Assault   Apartment
# 3     Assault   Apartment
# 4  Theft Over       House

# %%
len(crimes_df)
# Out:
# 130167

# %%
# output to csv
crimes_df.to_csv('crimes_csv.csv')
